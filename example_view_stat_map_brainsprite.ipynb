# %%
from nilearn import datasets
import nibabel as nb
from nilearn import plotting
import numpy as np
# Out:
# /home/pbellec/env/brainsprite/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/pbellec/env/brainsprite/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/pbellec/env/brainsprite/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/pbellec/env/brainsprite/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/pbellec/env/brainsprite/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
# ...

# %%
# one motor contrast map from NeuroVault
motor_images = datasets.fetch_neurovault_motor_task()
stat_img = motor_images.images[0]

# %%
plotting.view_stat_map(stat_img,threshold=2,cut_coords=[-15,-25,35],opacity=0.5,draw_cross=True,dim=0,colorbar=True,annotate=True,title="Motor Activation")
# Out:
# /home/pbellec/env/brainsprite/lib/python3.5/site-packages/nilearn/image/resampling.py:505: UserWarning: Casting data from int16 to float32
#   warnings.warn("Casting data from %s to %s" % (data.dtype.name, aux))
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
#
# &lt;head&gt;
# &lt;/head&gt;
# &lt;body&gt;
#   &lt;div id=&quot;div_viewer&quot;&gt;
#     &lt;!-- this is the canvas that will feature the brain slices --&gt;
#     &lt;canvas id=&quot;3Dviewer&quot;&gt;
#     &lt;!-- load a hidden version of the sprite image that includes all (sagital) brain slices --&gt;
#     &lt;img id=&quot;spriteImg&quot; class=&quot;hidden&quot; src=&quot;...
